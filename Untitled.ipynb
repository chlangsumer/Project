# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('data.jpeg')

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (768, 850, 3)

# %%
# x, y, width, height = 200, 350, 450, 400
# cv2.rectangle(image, (x1, y1), (x2, y2), (255, 0, 0), 2)
image = cv2.rectangle(img, (150, 300), (800, 650), (255, 0, 0), 2)

# %%
plt.imshow(image)

# %%
# cropped_image = image[y1:y2, x1:x2]
cropped_image = img[300:650, 150:800]

# %%
cropped_image.shape
# Out:
# (350, 650, 3)

# %%
plt.imshow(cropped_image)

# %%
image=cv2.cvtColor(cropped_image, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(image)

# %%
cv2.imwrite('savedData.jpeg', cropped_image)
# Out:
# True
